# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.1/593.1 kB 26.8 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip -q /content/gdrive/Shareddrives/research/mosquito_early_prediction.v1i.yolov8.zip

# %%
# !yolo detect train data=/content/mosquito_early_prediction.v1i.yolov8/data.yaml model=yolov8s.pt epochs=500 imgsz=640 project=/content/gdrive/Shareddrives/research name=aidem801_500 batch=64 device=0 cache=disk
# Out:
# Ultralytics YOLOv8.0.112 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !yolo detect val model=/content/gdrive/Shareddrives/research/aidem801/weights/best.pt device=0 conf=0.001 data=/content/mosquito_early_prediction.v1i.yolov8/data.yaml
# Out:
# Ultralytics YOLOv8.0.104 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/mosquito_early_prediction.v1i.yolov8/valid/labels... 1078 images, 0 backgrounds, 0 corrupt: 100% 1078/1078 [00:00<00:00, 1618.43it/s]
# val: New cache created: /content/mosquito_early_prediction.v1i.yolov8/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 68/68 [00:10<00:00,  6.23it/s]
#                    all       1078       1303      0.942      0.947      0.951      0.858
#                  aedes       1078        646      0.915      0.915       0.91      0.795
#              non_aedes       1078        657      0.968      0.979      0.991      0.921
# Speed: 0.4ms preprocess, 2.9ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/val

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# !pip install -r /content/yolov5/requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15679, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 15679 (delta 1), reused 2 (delta 0), pack-reused 15672
# Receiving objects: 100% (15679/15679), 14.45 MiB | 28.73 MiB/s, done.
# Resolving deltas: 100% (10742/10742), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.5/585.5 kB 31.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 24.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip -q /content/gdrive/Shareddrives/research/mosquito_early_prediction.v1i.yolov5pytorch.zip

# %%
# !python /content/yolov5/train.py --img 640 --epochs 100 --batch-size 32 --data /content/mosquito_early_prediction.v1i.yolov5pytorch/data.yaml --weights yolov5s.pt --device 0 --project /content/gdrive/Shareddrives/research --name aidem501 --cache disk
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/mosquito_early_prediction.v1i.yolov5pytorch/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=disk, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/content/gdrive/Shareddrives/research, name=aidem501, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-168-gec2b853 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# ...

# %%
# !python /content/yolov5/val.py --weights /content/gdrive/Shareddrives/research/aidem501/weights/best.pt --data /content/mosquito_early_prediction.v1i.yolov5pytorch/data.yaml --img 640 --half --device 0 --conf-thres 0.001
# Out:
# val: data=/content/mosquito_early_prediction.v1i.yolov5pytorch/data.yaml, weights=['/content/gdrive/Shareddrives/research/aidem501/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=True, dnn=False
# requirements: /usr/local/lib/python3.10/dist-packages/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-168-gec2b853 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/yolov5/valid/labels.cache... 1078 images, 0 backgrounds, 0 corrupt: 100% 1078/1078 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 34/34 [00:09<00:00,  3.50it/s]
# ...

# %%
# !git clone https://github.com/ultralytics/yolov3  # clone
# !pip install -r /content/yolov3/requirements.txt  # install
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 10631, done.
# remote: Counting objects: 100% (553/553), done.
# remote: Compressing objects: 100% (332/332), done.
# remote: Total 10631 (delta 347), reused 396 (delta 220), pack-reused 10078
# Receiving objects: 100% (10631/10631), 9.77 MiB | 17.68 MiB/s, done.
# Resolving deltas: 100% (7146/7146), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.4/591.4 kB 25.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 12.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip -q /content/gdrive/Shareddrives/research/mosquito_early_prediction.v1i.yolov5pytorch.zip

# %%
# !python /content/yolov3/train.py --img 640 --epochs 100 --batch-size 32 --data /content/mosquito_early_prediction.v1i.yolov5pytorch/data.yaml --weights yolov3s.pt --device 0 --project /content/gdrive/Shareddrives/research --name aidem301 --cache disk
# Out:
# train: weights=yolov3s.pt, cfg=, data=/content/mosquito_early_prediction.v1i.yolov5pytorch/data.yaml, hyp=yolov3/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=disk, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/content/gdrive/Shareddrives/research, name=aidem301, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2656 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv3 🚀 v9.6.0-78-g4d6393c1 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# ...

# %%
# !python /content/yolov5/val.py --weights /content/gdrive/Shareddrives/research/aidem501/weights/best.pt --data /content/mosquito_early_prediction.v1i.yolov5pytorch/data.yaml --img 640 --half --device 0 --conf-thres 0.001
